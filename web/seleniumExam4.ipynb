# %%
"""
연습 사이트: https://[Log in to view URL]
"""

from selenium import webdriver
from selenium.webdriver.common.by import By


# -------------------------------------------------
# 공통: 드라이버 실행 및 1페이지 접속
# -------------------------------------------------
driver = webdriver.Edge()
driver.get("https://quotes.toscrape.com/")


# =================================================
# 문제 1 (기초)
# =================================================
"""
[문제 1]
1페이지에서 모든 명언(text)과 저자(author)를 출력하세요.

출력 형식:
명언 - 저자

조건:
- find_elements()를 사용하세요.
- 각 quote 블록 안에서 다시 요소를 찾으세요.
"""
results = []

print("\n=== 1페이지 수집 ===")
quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

for block in quote_blocks:
    quote_text = block.find_element(By.CLASS_NAME, "text").text
    author = block.find_element(By.CLASS_NAME, "author").text
    print(quote_text, "-", author)

# =================================================
# 문제 2 (중급)
# =================================================
"""
[문제 2]
1페이지에서 각 명언의 태그 개수를 함께 출력하세요.

출력 형식 예:
명언 - 저자 (태그 3개)

조건:
- 태그는 class="tag" 입니다.
- 태그는 여러 개일 수 있습니다.
- len()을 활용하세요.
"""
print("=== 1페이지 각 명언의 태그 개수 ===")
quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

for block in quote_blocks:
    quote_text = block.find_element(By.CLASS_NAME, "text").text
    author = block.find_element(By.CLASS_NAME, "author").text
    tag_elements = block.find_elements(By.CLASS_NAME, "tag")
    tags = [t.text for t in tag_elements]
    print(f"{quote_text}, - {author} (태그 {len(tag_elements)}개)")

# =================================================
# 문제 3 (중상)
# =================================================
"""
[문제 3]
2페이지까지 이동하여 총 몇 개의 명언을 수집했는지 출력하세요.

조건:
- Next 버튼을 클릭하세요.
- 반복문을 사용하세요.
- 페이지 이동 후 다시 요소를 수집하세요.
"""
print("=== 2페이지 이동 포함 수집된 명언의 개수 ===")
total_quote = 0
current_page = 1
MAX_PAGES = 2

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")
    total_quote += len(quote_blocks)

    # 2페이지까지니까, 1페이지에서만 next를 누르면 됨 
    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CLASS_SELECTOR, "li.next a")
        if not next_buttons:
            break
        next_buttons[0].click()

    current_page += 1

print("2페이지까지 총 명언 개수 :", total_quote)

# =================================================
# 문제 4 (활용)
# =================================================
"""
[문제 4]
3페이지까지 수집하면서, 태그에 "love"가 포함된 명언만 출력하세요.

출력 형식:
[LOVE] 명언 - 저자

조건:
- 태그 목록(tags) 안에 "love"가 있으면 출력합니다.
"""
print("=== 3페이지까지 수집 후 태그에 love가 포함된 명언만 출력 ===")
driver.get("https://quotes.toscrape.com/")

current_page = 1
MAX_PAGES = 3

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

    for block in quote_blocks:
        quote_text = block.find_element(By.CLASS_NAME, "text").text
        author = block.find_element(By.CLASS_NAME, "author").text
        tag_elements = block.find_element(By.CLASS_NAME, "tag")
        tags = [t.text for t in tag_elements]

        if "love" in tags:
            print(f"[love] {quote_text} - {author}")

    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")
        if not next_buttons:
            break
        next_buttons[0].click()
        
    current_page += 1

# =================================================
# 문제 5 (도전)
# =================================================
"""
[문제 5]
3페이지까지 수집한 뒤, 저자별로 명언이 몇 개 있는지 출력하세요.

출력 예:
Albert Einstein : 2개
Mark Twain : 3개

조건:
- 딕셔너리를 사용하세요.
- key = author, value = 개수
"""
driver.get("https://quotes.toscrape.com/")

author_count = {}
current_page = 1
MAX_PAGES = 3

while current_page <= MAX_PAGES:
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

    for block in quote_blocks:
        author = block.find_element(By.CLASS_NAME, "author").text

        # 딕셔너리 집계 패턴
        # author가 없으면 0에서 시작해서 1씩 증가
        author_count[author] = author_count.get(author, 0) + 1

    if current_page < MAX_PAGES:
        next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")
        if not next_buttons:
            break
        next_buttons[0].click()
    
    current_page += 1

    for author, count in author_count.items():
        print(f"{author} : {count}개")

# -------------------------------------------------
# 브라우저 종료
# -------------------------------------------------
driver.quit()
# Out:
# === 1페이지 수집 ===
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.” - Albert Einstein
# “It is our choices, Harry, that show what we truly are, far more than our abilities.” - J.K. Rowling
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.” - Albert Einstein
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.” - Jane Austen
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.” - Marilyn Monroe
# “Try not to become a man of success. Rather become a man of value.” - Albert Einstein
# “It is better to be hated for what you are than to be loved for what you are not.” - André Gide
# “I have not failed. I've just found 10,000 ways that won't work.” - Thomas A. Edison
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.” - Eleanor Roosevelt
# “A day without sunshine is like, you know, night.” - Steve Martin
# === 1페이지 각 명언의 태그 개수 ===
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”, - Albert Einstein (태그 4개)
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”, - J.K. Rowling (태그 2개)
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”, - Albert Einstein (태그 5개)
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”, - Jane Austen (태그 4개)
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”, - Marilyn Monroe (태그 2개)
# “Try not to become a man of success. Rather become a man of value.”, - Albert Einstein (태그 3개)
# “It is better to be hated for what you are than to be loved for what you are not.”, - André Gide (태그 2개)
# “I have not failed. I've just found 10,000 ways that won't work.”, - Thomas A. Edison (태그 4개)
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”, - Eleanor Roosevelt (태그 1개)
# “A day without sunshine is like, you know, night.”, - Steve Martin (태그 3개)
# === 2페이지 이동 포함 수집된 명언의 개수 ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 88
#      86 # 2페이지까지니까, 1페이지에서만 next를 누르면 됨
#      87 if current_page < MAX_PAGES:
# ---> 88     next_buttons = driver.find_elements(By.CLASS_SELECTOR, "li.next a")
#      89     if not next_buttons:
#      90         break
#
# AttributeError: type object 'By' has no attribute 'CLASS_SELECTOR'

# %%
# Selenium이란?
# - 브라우저를 자동으로 조작하는 도구

# 기본 사용 흐름
# 1. 브라우저 실행
# 2. 웹 페이지 접속
# 3. 요소 찾기
# 4. 데이터 추철
# 5. 필요 시 클릭/이동
# 6. 브라우저 종료

# 요소 찾는 방법
# 1. TAG_NAME
# driver.find_elements(By.TAG_NAME, "div")
# 2. CLASS_NAME
# driver.find_element(By.CLASS_NAME, "quote")
# 3. id
# driver.find_element(By.ID, "quotes")
# 4. CSS_SELECTOR
# driver.find_element(By.CSS_SELECTOR, "li.next a")
5. XPath
# # driver.find_element(
#     By. XPATH,
#     "//div[@class='quote']/span[@class='text']"
# )
# find_element vs find_elements
# find_element : 요소 1개 찾기
# find_elements : 여러 개를 찾기(리스트로 반환)
# for block in quote_blocks:
#   text = block.find_element(By.CLASS_NAME, "text").text
# next_button = driver.find_element((By.CSS_SELECTOR, "li.next a")

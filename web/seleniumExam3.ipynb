# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# ========================================
# 0) 브라우저 실행 + 페이지 접속
# ========================================
driver = webdriver.Edge()
driver.get("https://quotes.toscrape.com/")

# ========================================
# 1) 한 페이지에서 여러 명언 수집하기
# ========================================

# 수집한 데이터를 저장할 리스트
results = []

print("===== 1페이지 수집 시작 =====")

quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

for block in quote_blocks:
    # 각 블록 안에서 필요한 데이터 찾기
    quote_text = block.find_element(By.CLASS_NAME, "text").text
    author = block.find_element(By.CLASS_NAME, "author").text

    # 태그는 여러 개일 수 있으므로 find_elements 사용
    tag_elements = block.find_elements(By.CLASS_NAME, "tag")
    
    tags = [t.text for t in tag_elements]
    # 리스트 컴프리헨션을 사용하여 각 tag 요소의 텍스트만 추출
    #   - (컴프리헨션 : 반복문을 이용해 새로운 컬렉션을 만드는 축약 문법)
    #   - [표현식 for 변수 in 반복가능객체]
    # 최종적으로 tags는 문자열 리스트 형태가 됨
    # 아래 형태와 똑같다.
    # tags = []
    # for i in tag_elements:
    #     tags.append(t.text)

    results.append({
        "page": 1,
        "quote": quote_text,
        "author": author,
        "tags": tags
    })
    print(author, "-", quote_text)

print("현재까지 수집 개수 :", len(results))

# 브라우저 종료
driver.quit()
# Out:
# ===== 1페이지 수집 시작 =====
# Albert Einstein - “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# J.K. Rowling - “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# Albert Einstein - “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# Jane Austen - “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# Marilyn Monroe - “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# Albert Einstein - “Try not to become a man of success. Rather become a man of value.”
# André Gide - “It is better to be hated for what you are than to be loved for what you are not.”
# Thomas A. Edison - “I have not failed. I've just found 10,000 ways that won't work.”
# Eleanor Roosevelt - “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# Steve Martin - “A day without sunshine is like, you know, night.”
# 현재까지 수집 개수 : 10

# %%
# ========================================
# 2) 다음 페이지 이동 + 반복 수집
# ========================================

# 최대 몇 페이지까지 수집할지 제한하는 상수 (상수는 대문자로 써주는 게 관례)
# 무한 크롤링을 방지하기 위한 안전 장치
MAX_PAGES = 3

# 현재 페이지 번호를 추적하기 위한 변수
current_page = 1

while current_page < MAX_PAGES:
    # Next 버튼 찾기
    # "li.next a"는 class="next"를 가진 li안의 a태그 의미
    next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")

    # Next 버튼이 없으면 종료
    if not next_buttons:
        print("다음 페이지가 없어 종료합니다.")
        break

    # 다음 페이지로 이동
    next_buttons[0].click()

    # 페이지 번호 1 증가 
    current_page += 1

    # 현재 수집 중인 페이지 번호 출력
    print(f"\n===== {current_page}페이지 수집 중 =====")

    # 새 페이지에서 다시 quote 블록 수집
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

    for block in quote_blocks:
        quote_text = block.find_element(By.CLASS_NAME, "text").text
        author = block.find_element(By.CLASS_NAME, "author").text
        tags_elements = block.find_elements(By.CLASS_NAME, "tag")
        tags = [t.text for i in tag_elements]

        results.append({
            "page": 1,
            "quote": quote_text,
            "author": author,
            "tags": tags
        })

print("\n최종 수집 개수 :", len(results))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:500, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     499     self.putheader(header, value)
# --> 500 self.endheaders()
#     502 # If we're given a body we start sending that in chunks.
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1353, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1352     raise CannotSendHeader()
# -> 1353 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1113, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1112 del self._buffer[:]
# -> 1113 self.send(msg)
#    1115 if message_body is not None:
#    1116
#    1117     # create a consistent interface to message_body
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\http\client.py:1057, in HTTPConnection.send(self, data)
#    1056 if self.auto_open:
# -> 1057     self.connect()
#    1058 else:
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:331, in HTTPConnection.connect(self)
#     330 def connect(self) -> None:
# --> 331     self.sock = self._new_conn()
#     332     if self._tunnel_host:
#     333         # If we're tunneling it means we're connected to our proxy.
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connection.py:219, in HTTPConnection._new_conn(self)
#     218 except OSError as e:
# --> 219     raise NewConnectionError(
#     220         self, f"Failed to establish a new connection: {e}"
#     221     ) from e
#     223 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: HTTPConnection(host='localhost', port=58478): Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[2], line 15
#      10 current_page = 1
#      12 while current_page < MAX_PAGES:
#      13     # Next 버튼 찾기
#      14     # "li.next a"는 class="next"를 가진 li안의 a태그 의미
# ---> 15     next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")
#      17     # Next 버튼이 없으면 종료
#      18     if not next_buttons:
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:847, in WebDriver.find_elements(self, by, value)
#     843     return self.execute_script(find_element_js, by.to_dict())
#     845 # Return empty list if driver returns null
#     846 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 847 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:443, in WebDriver.execute(self, driver_command, params)
#     440     elif "sessionId" not in params:
#     441         params["sessionId"] = self.session_id
# --> 443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
#     446     self.error_handler.check_response(response)
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:407, in RemoteConnection.execute(self, command, params)
#     405 trimmed = self._trim_large_entries(params)
#     406 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 407 return self._request(command_info[0], url, body=data)
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:431, in RemoteConnection._request(self, method, url, body)
#     428     body = None
#     430 if self._client_config.keep_alive:
# --> 431     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     432     statuscode = response.status
#     433 else:
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\poolmanager.py:457, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     455     response = conn.urlopen(method, url, **kw)
#     456 else:
# --> 457     response = conn.urlopen(method, u.request_uri, **kw)
#     459 redirect_location = redirect and response.get_redirect_location()
#     460 if not redirect_location:
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     838 elif isinstance(new_e, (OSError, HTTPException)):
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#     846 # Keep track of the error for the retry warning.
#
# File c:\Users\202-22\AppData\Local\Programs\Python\Python314\Lib\site-packages\urllib3\util\retry.py:535, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     533 if new_retry.is_exhausted():
#     534     reason = error or ResponseError(cause)
# --> 535     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     537 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     539 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=58478): Max retries exceeded with url: /session/32c0710fec59610aadde73495ef4ff00/elements (Caused by NewConnectionError("HTTPConnection(host='localhost', port=58478): Failed to establish a new connection: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다"))
